# %%
import os
from nustar_gen import info, utils, wrappers, diagnostic
import numpy as np
import astropy.units as u
from astropy.io.fits import getdata
import matplotlib.pyplot as plt
from importlib import reload
reload(diagnostic)
# Out:
# <module 'nustar_gen.diagnostic' from '/Users/bwgref/science/local/git/nustar-gen-utils/nustar_gen/diagnostic.py'>

# %%
obs = info.Observation(seqid='60021096001', path='./')

# %%
obs.exposure_report()
# Out:
# Exposure for FPMA, mode 01 is:       27.6 ks
# Exposure for FPMA, mode 06 is:      1.932 ks
#
# Exposure for FPMB, mode 01 is:      27.55 ks
# Exposure for FPMB, mode 06 is:       1.93 ks

# %%
diagnostic.goes_lightcurve(obs)

# %%
diagnostic.compare_sun_spec(obs, en_range = (1.6, 10), en_bins= 30)
